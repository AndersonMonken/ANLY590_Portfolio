# %%
import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow.keras.layers as tfkl
import numpy as np
import matplotlib.pyplot as plt

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### regression
#
# Let's start by using `keras` to make a neural network for a simple regression task where both the input and the output as 1-dimensional. Below is some code that will produce the dataset for you to train on.
#
# Here are some general steps to follow:
# 1. Define your model by passing `tfk.Sequential` a list of layers (found in `tf.keras.layers`, which is already imported for you by the shorter name `tfkl`, since you will use this module many times.
# 2. Your first layers should be a `tfkl.Input` layer that specifies the shape of the input (it will automatically include an empty first dimension with size `None` as a placehold for the batch size).
# 3. The rest of your layers should be `tfkl.Dense` layers; you will be to specify the number of neurons/units as well as the activation function (you can find those in `tf.nn`, and you can use `None` for a "linear" activation function, $f(x)=x$). Make sure you pick an output function that makes sense for this prediction task!
# 4. Choose an appropriate optimizer from `tfk.optimizers` and an appropriate loss function from `tfk.losses` (both are classes that wil need to be initialized), and then pass them to `model.compile` to compile your model.
# 5. Call `model.fit` to fit your model and collect the results
# 6. Plot your training curve (loss vs training step)
# 7. Call your model (`model(...)`) on a grid of inputs (code to make the grid provided) and plot the relationship your model learned against the true relationship (defined as `f` in the code below).

# %%
f = lambda x: 0.2 * x**2 * np.sin(2 * np.pi * x / 6)
def regression_data(N):
  x = np.random.uniform(low=-5.0, high=5.0, size=(N, 1)).astype(np.float32)
  e = 0.2 * np.random.normal(size=(N, 1)).astype(np.float32)
  f = lambda x: 0.2 * x**2 * np.sin(2 * np.pi * x / 6)
  y = f(x) + e
  return x, y

N = 100
x_train, y_train = regression_data(N)
x_test, y_test = regression_data(N)

plt.scatter(x_train, y_train, s=10)
plt.show()

# %%
try:
    del model
except:
    pass

# %%
a = tf.nn.tanh

model = tfk.Sequential(
    [tfkl.InputLayer((1,)),
    tfkl.Dense(5, activation=a),
    tfkl.Dense(5, activation=a),
    tfkl.Dense(5, activation=a),
    tfkl.Dense(1, activation = None)])

# %%
# loss = tfk.losses.MeanSquaredError()
# opt = tfk.optimizers.Adam()
# model.compile(opt, loss)

# model.summary()

# history = model.fit(x_train, y_train, epochs=1000, verbose = 0)

# %%
cbs = [tfk.callbacks.EarlyStopping(min_delta = 0.001, patience = 2, verbose = 0)] # validation data loss check

ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(32).repeat().prefetch(10)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(100).repeat().prefetch(10)

loss = tfk.losses.MeanSquaredError()
opt = tfk.optimizers.Adam()
model.compile(opt, loss)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 10
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 76
# Trainable params: 76
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(ds_train, steps_per_epoch = 100, epochs=100000, callbacks=cbs, validation_data=ds_test, validation_steps = 1)
# Out:
# Train for 100 steps, validate for 1 steps
# Epoch 1/100000
# 100/100 [==============================] - 1s 6ms/step - loss: 2.8012 - val_loss: 2.7066
# Epoch 2/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 2.5043 - val_loss: 2.5012
# Epoch 3/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 2.2641 - val_loss: 2.2215
# Epoch 4/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 1.9386 - val_loss: 1.8727
# Epoch 5/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 1.6200 - val_loss: 1.5617
# Epoch 6/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 1.2955 - val_loss: 1.2025
# Epoch 7/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.8945 - val_loss: 0.8073
# Epoch 8/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5661 - val_loss: 0.5826
# Epoch 9/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4093 - val_loss: 0.4703
# Epoch 10/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3201 - val_loss: 0.3868
# Epoch 11/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2536 - val_loss: 0.3210
# Epoch 12/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2038 - val_loss: 0.2704
# Epoch 13/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1670 - val_loss: 0.2318
# Epoch 14/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1399 - val_loss: 0.2021
# Epoch 15/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1195 - val_loss: 0.1791
# Epoch 16/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1040 - val_loss: 0.1610
# Epoch 17/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0921 - val_loss: 0.1465
# Epoch 18/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0826 - val_loss: 0.1349
# Epoch 19/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0750 - val_loss: 0.1255
# Epoch 20/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0689 - val_loss: 0.1177
# Epoch 21/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0639 - val_loss: 0.1112
# Epoch 22/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0597 - val_loss: 0.1057
# Epoch 23/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0562 - val_loss: 0.1010
# Epoch 24/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0532 - val_loss: 0.0970
# Epoch 25/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0506 - val_loss: 0.0934
# Epoch 26/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0483 - val_loss: 0.0902
# Epoch 27/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0463 - val_loss: 0.0874
# Epoch 28/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0445 - val_loss: 0.0849
# Epoch 29/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0429 - val_loss: 0.0826
# Epoch 30/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0414 - val_loss: 0.0805
# Epoch 31/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0401 - val_loss: 0.0786
# Epoch 32/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0390 - val_loss: 0.0769
# Epoch 33/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0379 - val_loss: 0.0754
# Epoch 34/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0370 - val_loss: 0.0740
# Epoch 35/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0361 - val_loss: 0.0727
# Epoch 36/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0354 - val_loss: 0.0715
# Epoch 37/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0347 - val_loss: 0.0704
# Epoch 38/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0341 - val_loss: 0.0695
# Epoch 39/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0335 - val_loss: 0.0686
# Epoch 40/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0331 - val_loss: 0.0678
# Epoch 41/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0326 - val_loss: 0.0670
# Epoch 42/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0322 - val_loss: 0.0664
# Epoch 43/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0319 - val_loss: 0.0658
# Epoch 44/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0652
# Epoch 45/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0314 - val_loss: 0.0648
# Epoch 46/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0311 - val_loss: 0.0643
# Epoch 47/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0309 - val_loss: 0.0639

# %%
loss_vec = history.history['val_loss']
plt.plot(range(len(loss_vec)), loss_vec)
plt.show()

# %%
x_grid = np.linspace(x_train.min(), x_train.max(), 200).astype(np.float32)[:, np.newaxis]
y_true = f(x_grid)
y_hat = model(x_grid)
plt.plot(x_grid, y_true, label = 'true')
plt.plot(x_grid, y_hat, label = 'predicted')
plt.show()

# %% [markdown]
# ### binary classification
#
# Here is another dataset that differs in two key ways from the regression example we just worked:
# 1. The input is now 2-dimensional
# 2. The targets are now binary classes
#
# Update your model to handle both of these changes and try fitting this new data. Think about the following:
# - input shape
# - output function
# - loss function
#
# Since visualizing the results is a bit tricky, we have provided some code for that.

# %%
N = 200
def binary_classification_data(N):
  x = np.random.uniform(low=-5, high=5, size=(N, 2))
  y = (x[:, 0] * x[:, 1] > 0).astype(np.int)
  return x, y

x_train, y_train = binary_classification_data(N)
x_test, y_test = binary_classification_data(N)

plt.figure(figsize=(7, 7))
plt.scatter(x_train[:, 0], x_train[:, 1], s=10, c=y_train, cmap='coolwarm')
plt.show()

# %%
a = tf.nn.relu

model = tfk.Sequential(
    [tfkl.InputLayer((2,)),
    tfkl.Dense(5, activation=a),
    tfkl.Dense(5, activation=a),
    tfkl.Dense(1, activation = tf.nn.sigmoid)])

# %%
log_dir = "./model_logs"
cbs = [tfk.callbacks.EarlyStopping(min_delta = 0.001, patience = 2, verbose = 0)] #,
     # tfk.callbacks.TensorBoard(log_dir = log_dir)] # validation data loss check

ds_train = tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(32).repeat().prefetch(10)
ds_test = tf.data.Dataset.from_tensor_slices((x_test,y_test)).batch(100).repeat().prefetch(10)

loss = tfk.losses.BinaryCrossentropy()
opt = tfk.optimizers.Adam()
model.compile(opt, loss)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 5)                 15
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 51
# Trainable params: 51
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(ds_train, steps_per_epoch = 100, epochs=100000, callbacks=cbs, validation_data=ds_test, validation_steps = 1)
# Out:
# Train for 100 steps, validate for 1 steps
# Epoch 1/100000
# 100/100 [==============================] - 1s 7ms/step - loss: 0.6257 - val_loss: 0.5439
# Epoch 2/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5440 - val_loss: 0.4547
# Epoch 3/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.4405 - val_loss: 0.3419
# Epoch 4/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.3292 - val_loss: 0.2481
# Epoch 5/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2480 - val_loss: 0.1908
# Epoch 6/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2023 - val_loss: 0.1557
# Epoch 7/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1760 - val_loss: 0.1321
# Epoch 8/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1564 - val_loss: 0.1150
# Epoch 9/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1419 - val_loss: 0.1021
# Epoch 10/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1316 - val_loss: 0.0922
# Epoch 11/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1249 - val_loss: 0.0837
# Epoch 12/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1159 - val_loss: 0.0767
# Epoch 13/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1094 - val_loss: 0.0712
# Epoch 14/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1056 - val_loss: 0.0662
# Epoch 15/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1004 - val_loss: 0.0616
# Epoch 16/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0953 - val_loss: 0.0576
# Epoch 17/100000
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0917 - val_loss: 0.0540
# Epoch 18/100000
# 100/100 [==============================] - 1s 8ms/step - loss: 0.0892 - val_loss: 0.0505
# Epoch 19/100000
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0848 - val_loss: 0.0474
# Epoch 20/100000
# 100/100 [==============================] - 1s 6ms/step - loss: 0.0811 - val_loss: 0.0447
# Epoch 21/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0794 - val_loss: 0.0420
# Epoch 22/100000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0760 - val_loss: 0.0395
# Epoch 23/100000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0725 - val_loss: 0.0373
# Epoch 24/100000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0701 - val_loss: 0.0352
# Epoch 25/100000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0684 - val_loss: 0.0331
# Epoch 26/100000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0652 - val_loss: 0.0312
# Epoch 27/100000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0624 - val_loss: 0.0296
# Epoch 28/100000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.0613 - val_loss: 0.0279
# Epoch 29/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0586 - val_loss: 0.0264
# Epoch 30/100000
# 100/100 [==============================] - 0s 5ms/step - loss: 0.0561 - val_loss: 0.0250
# Epoch 31/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0544 - val_loss: 0.0238
# Epoch 32/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0533 - val_loss: 0.0225
# Epoch 33/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0509 - val_loss: 0.0214
# Epoch 34/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0488 - val_loss: 0.0206
# Epoch 35/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0482 - val_loss: 0.0196
# Epoch 36/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0462 - val_loss: 0.0187
# Epoch 37/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0446 - val_loss: 0.0179
# Epoch 38/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0433 - val_loss: 0.0173
# Epoch 39/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0427 - val_loss: 0.0166
# Epoch 40/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0409 - val_loss: 0.0160
# Epoch 41/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0394 - val_loss: 0.0155
# Epoch 42/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0392 - val_loss: 0.0149
# Epoch 43/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0377 - val_loss: 0.0143
# Epoch 44/100000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.0366 - val_loss: 0.0139
# Epoch 45/100000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.0135

# %%
loss_vec = history.history['loss']
plt.plot(range(len(loss_vec)), loss_vec)
plt.show()

# %%
def binary_preds(model, x_minmax=5):
  x_grid = np.linspace(-x_minmax, x_minmax, 100)
  mesh = np.meshgrid(x_grid, x_grid)
  xs_grid = np.stack(mesh, axis=-1)
  yhat = model(xs_grid).numpy().squeeze()


  plt.imshow(yhat, cmap='coolwarm')
  plt.colorbar()

binary_preds(model)
# Out:
# WARNING:tensorflow:Model was constructed with shape Tensor("input_2:0", shape=(None, 2), dtype=float32) for input (None, 2), but it was re-called on a Tensor with incompatible shape (100, 100, 2).
# WARNING:tensorflow:Layer dense_4 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %% [markdown]
# ### general classfication
#
# Finally we will download and train on some real data to learn about general classification. Here is some code that will download and show some metadata about the MNIST dataset -- a collectin of handwritten digits.
#
# Update your model to work on this data so that you model can predict the digit from its image. One new thing to keep in mind: these inputs are 2D. Later in the course we will learn about convolutional neural nets for handing such inputs more naturally, but for now, update your `tfkl.Input` layer to be 2-dimensional and then add a `tfkl.Flatten()` layer right after it to unravel the 2-d image into a 1-d vector of pixels.
#
# Again, visualalizing the output is a bit tricky, so we have provided some code to help.

# %%
import tensorflow_datasets as tfds

ds, metadata = tfds.load('mnist', with_info=True)
print(metadata)
# Out:
# tfds.core.DatasetInfo(
#     name='mnist',
#     version=3.0.1,
#     description='The MNIST database of handwritten digits.',
#     homepage='http://yann.lecun.com/exdb/mnist/',
#     features=FeaturesDict({
#         'image': Image(shape=(28, 28, 1), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=10),
#     }),
#     total_num_examples=70000,
#     splits={
#         'test': 10000,
#         'train': 60000,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@article{lecun2010mnist,
#       title={MNIST handwritten digit database},
#       author={LeCun, Yann and Cortes, Corinna and Burges, CJ},
#       journal={ATT Labs [Online]. Available: http://yann.lecun.com/exdb/mnist},
#       volume={2},
#       year={2010}
#     }""",
#     redistribution_info=,
# )

# %%
a = tf.nn.softplus

model = tfk.Sequential([
    tfkl.InputLayer((28, 28, 1)),
    tfkl.Flatten(),
    tfkl.Dense(100, activation = a),
    tfkl.Dense(100, activation = a),
    tfkl.Dense(20, activation = a),
    tfkl.Dense(10, activation = tf.nn.softmax)
])

model.compile(optimizer=tfk.optimizers.Adam(), loss=tfk.losses.SparseCategoricalCrossentropy()) # one and only one of the classes, no cross classification
# categorical cross entropy - could be a vector adding up to 1 and multiple ratios

# %%
preprocess = lambda d: (tf.cast(d['image'], tf.float32) / 255., d['label'])

ds_train = ds['train'].map(preprocess).cache().batch(32).repeat().prefetch(10)
ds_test = ds['test'].take(1000).map(preprocess).cache().batch(1000).repeat().prefetch(10)
cbs = [tfk.callbacks.EarlyStopping(min_delta = 0.001, patience = 5, verbose = 0)]

results = model.fit(
ds_train, steps_per_epoch = 100, epochs = 1000, validation_data = ds_test, validation_steps = 1, callbacks = cbs)
# Out:
# Train for 100 steps, validate for 1 steps
# Epoch 1/1000
# 100/100 [==============================] - 7s 72ms/step - loss: 1.4443 - val_loss: 0.6168
# Epoch 2/1000
# 100/100 [==============================] - 2s 18ms/step - loss: 0.5428 - val_loss: 0.3962
# Epoch 3/1000
# 100/100 [==============================] - 3s 33ms/step - loss: 0.4396 - val_loss: 0.3473
# Epoch 4/1000
# 100/100 [==============================] - 5s 48ms/step - loss: 0.3596 - val_loss: 0.3094
# Epoch 5/1000
# 100/100 [==============================] - 7s 65ms/step - loss: 0.3282 - val_loss: 0.2983
# Epoch 6/1000
# 100/100 [==============================] - 3s 34ms/step - loss: 0.3101 - val_loss: 0.2711
# Epoch 7/1000
# 100/100 [==============================] - 3s 33ms/step - loss: 0.2697 - val_loss: 0.2792
# Epoch 8/1000
# 100/100 [==============================] - 3s 30ms/step - loss: 0.2918 - val_loss: 0.2407
# Epoch 9/1000
# 100/100 [==============================] - 9s 93ms/step - loss: 0.2697 - val_loss: 0.2532
# Epoch 10/1000
# 100/100 [==============================] - 4s 35ms/step - loss: 0.2754 - val_loss: 0.2046
# Epoch 11/1000
# 100/100 [==============================] - 2s 23ms/step - loss: 0.2299 - val_loss: 0.2159
# Epoch 12/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2529 - val_loss: 0.1800
# Epoch 13/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.2350 - val_loss: 0.1779
# Epoch 14/1000
# 100/100 [==============================] - 1s 10ms/step - loss: 0.1974 - val_loss: 0.1723
# Epoch 15/1000
# 100/100 [==============================] - 3s 31ms/step - loss: 0.2485 - val_loss: 0.1520
# Epoch 16/1000
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2150 - val_loss: 0.1944
# Epoch 17/1000
# 100/100 [==============================] - 1s 5ms/step - loss: 0.1998 - val_loss: 0.1782
# Epoch 18/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1792 - val_loss: 0.1680
# Epoch 19/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1765 - val_loss: 0.1491
# Epoch 20/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1864 - val_loss: 0.1646
# Epoch 21/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1572 - val_loss: 0.1218
# Epoch 22/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1607 - val_loss: 0.1531
# Epoch 23/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1617 - val_loss: 0.1434
# Epoch 24/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1534 - val_loss: 0.1447
# Epoch 25/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1448 - val_loss: 0.1283
# Epoch 26/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1566 - val_loss: 0.1437

# %%
def mnist_viz(model):
  ims, labels = next(iter(ds['test'].map(preprocess).batch(20)))
  yhat = model(ims)
  ypred = tf.argmax(yhat)

  plt.figure(figsize=(10, 40))
  for i in range(10):
    plt.subplot(10, 2, 2*i+1)
    plt.imshow(ims[i].numpy().squeeze(), cmap='bone')
    plt.subplot(10, 2, 2*i+2)
    plt.bar(np.arange(10), yhat[i].numpy())
    plt.ylim([0, 1])
  plt.show()

mnist_viz(model)
